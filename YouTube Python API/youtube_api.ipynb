# %%
import requests
import pandas as pd
import time
import os
import csv
import config

# %% [markdown]
# # API Key
# The first step is to grab an API key which can be different for different API's. Since we want to grab data from a Youtube  we'll get an youtube API key from [here](https://www.slickremix.com/docs/get-api-key-for-youtube/)

# %% [markdown]
# ## Store, Hide and get API key
# One option to hide an API key is to store is as an environment variable. By accessing Control Panel > System and Security > System > Advanced Settings. Then click on the option <Environment Variables> and select "Add New". Then give the varibale a descriptive name **XXX_API_KEY** and past the variable value.
#
# [Follow a tuturial here](https://rapidapi.com/blog/how-to-hide-an-api-key-with-python/)
#
# To call the API_KEY just
# ```
# Import os
# API_KEY = os.environ.get('XXX_API_KEY')
# ```
#
# For the **Channel ID** use the following method:
# - Go to the channel page you want > click on a video from the "VIDEOS" section > then access the channel again clicking on the channel icon under that video. In the URL you will have `"https://www.youtube.com/channel/{channel ID}"`

# %%
# retrieve API key from environment variables
API_KEY = os.environ.get('YOUTUBE_API_KEY')

# %% [markdown]
# # Just using a config.py and .gitignore to hide the API key

# %%
API_KEY = config.YOUTUBE_API_KEY
Channel_id = 'UCsG5dkqFUHZO6eY9uOzQqow'
page_token = ''

# %%
API_KEY
# Out:
# 'AIzaSyBZTJj6lwxItLINdWM5VCPqnZ9xUn5eSoo'

# %% [markdown]
# ## Testing a random API request
# The get() method grabs the data located at the "github url" and the json() method returns a JSON object in the response

# %%
# Make a random API call
response = requests.get('https://api.github.com').json()
response
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %% [markdown]
# # Working with the Youtube API
# This is the location of our data, now we just need to define what type of data we want to collect, the best way of figuring out which parameters and properties to add to the URL is read the [Official documentation](https://developers.google.com/youtube/v3/docs/search)

# %%
# Root URL
root_url = "https://www.googleapis.com/youtube/v3/"

# %%
search_params = "search?key=" + API_KEY + "&channelId=" + Channel_id + "&part=snippet,id&order=date&maxResults=10000"+ page_token

# %% [markdown]
# We’re performing a “search” through the YouTube API. Everything to the right of the '?' is parameters we add to request specific information.
#
#  - First, we add our API key that’s stored in the API_KEY variable in this key parameter.
#  - We specify the channel ID we want to collect information from.
#  - Next is the part parameter where we’re specifying that we want snippet and ID data. From the documentation, it tells us what data we can expect to get when we ask for snippet and ID data.
#  - Order the data by date and then we want the maxResults of 10000 videos in our API call.
#  - Lastly, the pageToken is a token, which is a code, that is needed to get to the next page of the search results. We’ll deal with this later when we try to extract all the data.
#  > As described in https://www.stratascratch.com/blog/working-with-python-apis-for-data-science-project/

# %%
url = root_url + search_params

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'k3BO6O0tfr6AMl-9ifPskk6zKYM',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'PT',
#  'pageInfo': {'totalResults': 1005, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'RMAyq97JwQAMlOqsySJrIR_VJOY',
#    'id': {'kind': 'youtube#video', 'videoId': 'R4mebR724Pg'},
#    'snippet': {'publishedAt': '2021-09-17T21:47:42Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Mason Ho&#39;s 4 Favorite Electric Acid Boards REVEALED',
#     'description': 'With ten Electric Acid Surfboards in his quiver, Mason has to decide which four boards he will hold onto.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-17T21:47:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'HFzuqyenyypw_V3aCqKB5gmMAtk',
#    'id': {'kind': 'youtube#video', 'videoId': 'RF_w8EQVFnY'},
#    'snippet': {'publishedAt': '2021-09-16T20:45:56Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Kolohe Andino vs Griffin Colapinto vs Ian Crane In A Hometown Showdown | Surf100 Lower Trestles',
#     'description': 'Inside 100-minute wave riding expo at Lower Trestles with Kolohe Andino, Griffin Colapinto, and Ian Crane. The full show is anchored with the no-holds-barred ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RF_w8EQVFnY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RF_w8EQVFnY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RF_w8EQVFnY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-16T20:45:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '79cwQPiSYAfmTjssY6DZFFbBwfs',
#    'id': {'kind': 'youtube#video', 'videoId': 'LUdqckbhzwY'},
#    'snippet': {'publishedAt': '2021-09-13T21:53:44Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'A 100% Authentic New Zealand Surf Film | &#39;Bro Town&#39;',
#     'description': 'When it comes to New Zealand, local boys Elliot Paerata Reid, Kehu Butler, Ware Wano, and Dune Kennings know exactly when to be, where to be, and how ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LUdqckbhzwY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LUdqckbhzwY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LUdqckbhzwY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-13T21:53:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YBNj-W6BW1Ms3iT7IgwiWCls2ac',
#    'id': {'kind': 'youtube#video', 'videoId': '9rd31N1EOwQ'},
#    'snippet': {'publishedAt': '2021-09-12T17:59:39Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Dane Reynolds, Mason Ho, And Mikey February Face-off At Surf100 Mexico',
#     'description': 'Surf100 is a wave riding exposition that takes place over a single, 100-minute period and is judged live, at a later date, by the internet. In this edition, Dane ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9rd31N1EOwQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9rd31N1EOwQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9rd31N1EOwQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-12T17:59:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'w3cZBOqBRJjGRfdKh3ddp4H85Vg',
#    'id': {'kind': 'youtube#video', 'videoId': 'w6CTQfDjW9o'},
#    'snippet': {'publishedAt': '2021-09-11T12:53:13Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'More Raw Footage Of The WSL Finalists Warming Up At Lowers | 9/7/21',
#     'description': 'Another day, another Lowers session with world title contenders scrapping for every bit of warm-up they can get. Watch the best clips of Gabriel Medina, Connor ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w6CTQfDjW9o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/w6CTQfDjW9o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/w6CTQfDjW9o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-11T12:53:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X6CuhGhiOmdMV0n96n-2fQooRkc',
#    'id': {'kind': 'youtube#video', 'videoId': 'LURSOgoQGgI'},
#    'snippet': {'publishedAt': '2021-09-10T14:53:12Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'South African Charger Beyrick De Vries Is Ready For The Upcoming Challenger Series | DBN',
#     'description': 'Unlike other CT hopefuls from nations that invest more in surfing, Beyrick has not had the luxury of financial freedom, government-subsidized athlete ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LURSOgoQGgI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LURSOgoQGgI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LURSOgoQGgI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-10T14:53:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9arHTqoXJo8G3hLmaGsL-NqVwaU',
#    'id': {'kind': 'youtube#video', 'videoId': 'CmmoJk2nj60'},
#    'snippet': {'publishedAt': '2021-09-09T20:16:27Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Chippa Wilson And The Adelio Team Hit Every Ramp In Sight | Solace',
#     'description': "Chippa Wilson, Koby Perkovich, Robbie Rickard, and Ethan Solberg launch air after air in the Adelio Team's latest edit 'Solace.' Filmed by Dan Scott and ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CmmoJk2nj60/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CmmoJk2nj60/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CmmoJk2nj60/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-09T20:16:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-6k5uWKmw3tjDiziV76B7PyaItA',
#    'id': {'kind': 'youtube#video', 'videoId': 'wd2JDFpj31w'},
#    'snippet': {'publishedAt': '2021-09-09T03:19:47Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Total Backhand Control With Gatien Delahaye | Pitstops',
#     'description': 'From the Caribbean island of Guadeloupe, the 24-year-old Gatien Delahaye has developed total control on his backhand. His timing is near perfect, his body ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wd2JDFpj31w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wd2JDFpj31w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wd2JDFpj31w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-09T03:19:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hZkAXiTuxzlvhMdRTRrgx613SSg',
#    'id': {'kind': 'youtube#video', 'videoId': 'yO_216d6Esc'},
#    'snippet': {'publishedAt': '2021-09-08T05:47:26Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Slip, Slide And Sabotage | S.U.R.F. Episode 4 Frictionless',
#     'description': 'In the fourth and final episode of S.U.R.F. we will be crowning our winner of the inaugural Stab X Byron Bay Brewery TV show. The theme of this challenge is ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yO_216d6Esc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yO_216d6Esc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yO_216d6Esc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-08T05:47:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZgcKd75RmVIbUV9DBiHfRqPsgk0',
#    'id': {'kind': 'youtube#video', 'videoId': 'L0h2Ne_408c'},
#    'snippet': {'publishedAt': '2021-09-08T03:10:10Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'All-Star Crew Surfs Lowers Before The WSL Finals | Raw Clips 9/6/21',
#     'description': 'Based on the swell forecast, it looks like the WSL Finals will run sometime between Sunday, Sept. 12th, and Tuesday, Sept. 14th. For now, we can offer you 15 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L0h2Ne_408c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L0h2Ne_408c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L0h2Ne_408c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-08T03:10:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ktom-cmeoc9mrzAWhQDJUwOVFn4',
#    'id': {'kind': 'youtube#video', 'videoId': 'MO2d3F1OZDg'},
#    'snippet': {'publishedAt': '2021-09-06T01:42:57Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'A Full Review Of The ACSOD Monster | Joyride Board Test',
#     'description': "Alex Crews has been shaping out of the Gold Coast for the past decade. In recent years, he's refined his craft and is now consistently putting quality boards ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MO2d3F1OZDg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MO2d3F1OZDg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MO2d3F1OZDg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-06T01:42:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0-LMr46Ow6BXAvZaLE-7d8P2wWY',
#    'id': {'kind': 'youtube#video', 'videoId': 'i-t64DlVjR0'},
#    'snippet': {'publishedAt': '2021-09-03T22:00:02Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'A Test Run Of Six Used Surfboards | Off The Rack Surfboard Broker',
#     'description': "In this edition of Off The Rack, Schuyler Allen teams up with North Shore's smooth operator and backflip pioneer, Flynn Novak, and put Surfboard Broker's ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i-t64DlVjR0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i-t64DlVjR0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i-t64DlVjR0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-03T22:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'v1z9nO7BKXelG3HP5RnG57-JPFQ',
#    'id': {'kind': 'youtube#video', 'videoId': '_8p7O5fc4Sc'},
#    'snippet': {'publishedAt': '2021-09-02T18:16:15Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'This John Florence Doppelgänger Can Surf | Brodi Sale &#39;Live In The Moment&#39;',
#     'description': "When flying down the face of a wave, it's easy to mistake Brodi Sale for John Florence. The curly blonde hair, athletic stature, and amount of drive are noticeably ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_8p7O5fc4Sc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_8p7O5fc4Sc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_8p7O5fc4Sc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-02T18:16:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'syOyAzkQ0qWmJolaRSFvNtYIpAA',
#    'id': {'kind': 'youtube#video', 'videoId': 'IXPxlHhqp-A'},
#    'snippet': {'publishedAt': '2021-09-02T15:12:58Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Dead Kooks Shaper Profile | E.A.S.T. With Mason and Coco Ho',
#     'description': 'Eden Saul, the man behind Dead Kooks surfboards, has spent his career cranking out mesmerizing alternative surfboards. For this reason, we invited him to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IXPxlHhqp-A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IXPxlHhqp-A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IXPxlHhqp-A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-02T15:12:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2gSow2-iNxHhDcPmXptpL43MPow',
#    'id': {'kind': 'youtube#video', 'videoId': 'jMBxalU1d2w'},
#    'snippet': {'publishedAt': '2021-09-01T00:35:25Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Everything You Need To Know About &#39;The Ultimate Surfer&#39; Wave Pool',
#     'description': "Take an inside look at Kelly Slater's Surf Ranch, which hosted the reality TV show 'The Ultimate Surfer'. Read our episode 3 recap here: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jMBxalU1d2w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jMBxalU1d2w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jMBxalU1d2w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-01T00:35:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ASUN40l4EvLYDTmqOiy9jEHepmk',
#    'id': {'kind': 'youtube#video', 'videoId': 'JoPtBBqVfbM'},
#    'snippet': {'publishedAt': '2021-08-31T10:14:26Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Two Broken Surfboards GLUED Together?! |S.U.R.F Episode 3 Resourcefulness',
#     'description': "Resourcefulness: the ability to find quick and clever ways to overcome difficulties. In episode 3 of S.U.R.F., Ozzy Wright, Jake Vincent, Ari 'Krooky' Browne, and ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JoPtBBqVfbM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JoPtBBqVfbM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JoPtBBqVfbM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-31T10:14:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Z7da1ACVwNNA3WuKIDd2ja9dB1Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'xGrxuydv2nY'},
#    'snippet': {'publishedAt': '2021-08-29T23:14:26Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Testing The Haydenshapes Cohort_I During A Solid East Coast Swell',
#     'description': 'My first impression of The Haydenshapes Cohort_I was that it had a good amount of entry rocker. The beak flips up aggressively in the last eight inches, which ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xGrxuydv2nY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xGrxuydv2nY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xGrxuydv2nY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-29T23:14:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'k_1M5XCpyKFQCqvmBeZjqAytw8Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'MZhMAXjYE6k'},
#    'snippet': {'publishedAt': '2021-08-27T20:58:28Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Are Alternative Surfboards Just A Trend? | Surf100 Mexico',
#     'description': 'Over time boards have gotten smaller, wider, and in some cases softer. All these changes, whether slight or severe, have been a direct response to consumer ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MZhMAXjYE6k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MZhMAXjYE6k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MZhMAXjYE6k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-27T20:58:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LLX3u3a6oqVPqc_KuGN-ZoY0XtE',
#    'id': {'kind': 'youtube#video', 'videoId': '8CK6moGEvRA'},
#    'snippet': {'publishedAt': '2021-08-25T21:02:57Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'The Best Independent Surf Film You&#39;ll Watch This Week | &#39;Thunderbird&#39; By Colin Moran',
#     'description': 'Colin Moran, Chippa Wilson, Alex Knost, Andrew Doheny, Balaram Stack, Danny Fuller, Christian and Greyson Fletcher, Makua Rothman, and Ford Archbold ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8CK6moGEvRA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8CK6moGEvRA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8CK6moGEvRA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-25T21:02:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AqBK5t2GeEvfWXj7SbJwJ3sqePY',
#    'id': {'kind': 'youtube#video', 'videoId': 'df6K0AAJ-y4'},
#    'snippet': {'publishedAt': '2021-08-25T02:13:25Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Rainbows In The Rearview | A Surf Film By Albee Layer',
#     'description': "Albee Layer fits no mold. Let's start by scratching comp guy off the list. According to the WSL's website, he's competed in only one non big-wave event since ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/df6K0AAJ-y4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/df6K0AAJ-y4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/df6K0AAJ-y4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-25T02:13:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-Uh8X9YOF-uZ3S1_2NOsdjEnfMw',
#    'id': {'kind': 'youtube#video', 'videoId': '4erx2fu0V9k'},
#    'snippet': {'publishedAt': '2021-08-24T06:07:14Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Could You Perform Like This On A Board From The Late 1900s?  S.U.R.F. Episode 2',
#     'description': "How well can you surf a board that costs 24 beers and $100? | S.U.R.F. Ep. 2 'Uncover' Brought to you by Stab and Byron Bay Brewery, the show features four of ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4erx2fu0V9k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4erx2fu0V9k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4erx2fu0V9k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-24T06:07:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Zm1jGihnS1x2SjCer8XaiuxR2Yo',
#    'id': {'kind': 'youtube#video', 'videoId': '3u3ftJUHiuQ'},
#    'snippet': {'publishedAt': '2021-08-22T12:00:04Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Wait, This Board Has A Mechanical SPRING Inside?',
#     'description': "The Campbell Designed Chunky Toe features a mechanical spring in place of its stringer. What is a mechanical spring? We have no idea, and they won't tell us ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3u3ftJUHiuQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3u3ftJUHiuQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3u3ftJUHiuQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-22T12:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OzATh5QlCAzbrDfiRn8E6xDTrW0',
#    'id': {'kind': 'youtube#video', 'videoId': 'JfMZebb8ETc'},
#    'snippet': {'publishedAt': '2021-08-20T13:43:17Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'The Best 11-Year-Old Tube Rider On EARTH',
#     'description': "Meet Dylan Wilcoxen, lifetime Kanui Resort resident and the most adept pre-teen barrel rider we've ever seen. He also likes twin fins, fishing, and ice pops.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JfMZebb8ETc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JfMZebb8ETc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JfMZebb8ETc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-20T13:43:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PFHTFNzQjZuQqudhBTFxvP7KKBg',
#    'id': {'kind': 'youtube#video', 'videoId': 'uMRPTkhgpVE'},
#    'snippet': {'publishedAt': '2021-08-19T06:05:08Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Stylish Laybacks And Punk Rock Tap Dancing With Jaleesa Vincent',
#     'description': "Laced with spook, stylish frontside laybacks, fine embroidery, joyous tap dancing, love songs, and dark biblical themes, Jaleesa Vincent's 9-minute clip is a ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uMRPTkhgpVE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uMRPTkhgpVE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uMRPTkhgpVE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-19T06:05:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3blzUu2AEvTkZhyjzlP8eaMJ2do',
#    'id': {'kind': 'youtube#video', 'videoId': 'HEVbfDucd6A'},
#    'snippet': {'publishedAt': '2021-08-17T18:58:23Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'This Wave Looks Identical To Pipeline',
#     'description': 'Manuel Lezcano is a surfer from the Canary Islands that knows exactly where to be, and when. There are moments where everything lines up perfectly, and the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HEVbfDucd6A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HEVbfDucd6A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HEVbfDucd6A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-17T18:58:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fl3RbGN4cW2RBPlIJGFioBvXTIw',
#    'id': {'kind': 'youtube#video', 'videoId': 'F-Z45G9VgVc'},
#    'snippet': {'publishedAt': '2021-08-17T01:45:03Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': '4 Men Compete to surf the LONGEST wave | S.U.R.F. Ep. 1 &#39;Space&#39;',
#     'description': "Introducing S.U.R.F: a new medium-performance, four-part Stab TV show. Brought to you by Stab and Byron Bay Brewery, the show features four of Byron's most ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F-Z45G9VgVc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F-Z45G9VgVc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F-Z45G9VgVc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-17T01:45:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tr6P5XRZGr-ki8ApzPX1cfjZg90',
#    'id': {'kind': 'youtube#video', 'videoId': 'ITMS5eOIuYI'},
#    'snippet': {'publishedAt': '2021-08-15T01:40:00Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'What Happens When A World-Class High Performance Shaper Tries A Mid-Length With Harrison Roach?',
#     'description': "There are many ways one could surf a midlength, but Harrison Roach's approach is relatively unmatched. Watch his stroll on the JS Big Baron above.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ITMS5eOIuYI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ITMS5eOIuYI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ITMS5eOIuYI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-15T01:40:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-SGcN4CxcqTcyrGNjNZ3CWfvaNo',
#    'id': {'kind': 'youtube#video', 'videoId': '5UYS4BvtDPY'},
#    'snippet': {'publishedAt': '2021-08-13T22:43:44Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Introducing S.U.R.F: A Medium-Performance Surf Contest',
#     'description': "Brought to you by Stab and Byron Bay Brewery, the show features four of Byron's most colourful and irreverent surfers, competing in four unique challenges, ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5UYS4BvtDPY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5UYS4BvtDPY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5UYS4BvtDPY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-13T22:43:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RBKoepTFRFw9hgKsLefhbqBpXs4',
#    'id': {'kind': 'youtube#video', 'videoId': 'D8REk6H4Cck'},
#    'snippet': {'publishedAt': '2021-08-13T02:55:02Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'FINAL: Vans Stab High, Central America, Presented by Monster Energy: Episode 5',
#     'description': "Welcome to the Vans Stab High, Central America, Presented by Monster Energy final. It's time for our Stab Premium audience to choose this year's winner.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D8REk6H4Cck/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D8REk6H4Cck/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D8REk6H4Cck/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-13T02:55:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'N_F5Zv1vB2TncVgLXPX1y7leu1s',
#    'id': {'kind': 'youtube#video', 'videoId': '_y2Xg-I50eU'},
#    'snippet': {'publishedAt': '2021-08-12T02:48:50Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Taking The Stab in the Dark Winning Board For a Joyride | Sharpeye Inferno72',
#     'description': 'Does anyone else notice the amount of Sharpeye surfboards in rotation at the Corona Open Mexico? There seems to be a new favorite board brand amongst ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_y2Xg-I50eU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_y2Xg-I50eU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_y2Xg-I50eU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-12T02:48:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pvNWSYUJXBd62kqRADOHOY6S3kk',
#    'id': {'kind': 'youtube#video', 'videoId': 'TFJFzDiNvnc'},
#    'snippet': {'publishedAt': '2021-08-11T01:53:55Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Vans Stab High, Central America, Presented by Monster Energy: Episode 4',
#     'description': "Enough giggling and Imperials, it's time to narrow the playing field. Episode 4 of Vans Stab High, Central America, presented by Monster Energy, follows our ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TFJFzDiNvnc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TFJFzDiNvnc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TFJFzDiNvnc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-11T01:53:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5iiPZChPWZki7tJeWnugc9uMY1E',
#    'id': {'kind': 'youtube#video', 'videoId': 'GwxpMoFnNww'},
#    'snippet': {'publishedAt': '2021-08-10T16:50:15Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Did A Plumber Just Stomp A Full Rotation ? | Jai Walsh In &#39;Labyrinth&#39;',
#     'description': "The ongoing joke is that 'Labyrinth' is Jai's 'retirement clip'. When you work for cash as a plumber and surf for fun then trying to do your best surfing in front of a ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GwxpMoFnNww/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GwxpMoFnNww/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GwxpMoFnNww/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-10T16:50:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iuH3FFLH2F_tYRqdlB2D1_1zcZk',
#    'id': {'kind': 'youtube#video', 'videoId': 'eO2Ws1Rukd0'},
#    'snippet': {'publishedAt': '2021-08-09T20:04:15Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Stab’s Search For The World&#39;s Best Wetsuit',
#     'description': 'That ice-cold water will be here before you know it, watch above to see which wetsuit will give you the most bang for your buck. Wetsuits tested (All 3/2 wetsuits): ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eO2Ws1Rukd0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eO2Ws1Rukd0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eO2Ws1Rukd0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-09T20:04:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0E4Gqc2CpC_pZsR1zXEESPxNiow',
#    'id': {'kind': 'youtube#video', 'videoId': 'zk26PAQK45A'},
#    'snippet': {'publishedAt': '2021-08-07T04:55:42Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'XXL Waves At Teahupoo With Nathan Florence, Jack Robinson, And More',
#     'description': "The world's best big wave surfers including Nathan Florence, Lucas Chumbo, and more pull into massive bombs at Teahupoo in Tahiti. Watch More from Red ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zk26PAQK45A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zk26PAQK45A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zk26PAQK45A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-07T04:55:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mLGDmKyJgUXKtFwVPQt8AxsBBJg',
#    'id': {'kind': 'youtube#video', 'videoId': '0PtXWSmaJn4'},
#    'snippet': {'publishedAt': '2021-08-06T03:29:28Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Vans Stab High, Central America, Presented by Monster Energy: Episode 3',
#     'description': 'What exactly defines a Ladybird? According to our guest narrator, Coco Ho, “A ladybird is a 17 and under female surfer with an affinity for flight.” Sierra Kerr won ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0PtXWSmaJn4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0PtXWSmaJn4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0PtXWSmaJn4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-06T03:29:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6ETcNRPopb8ccNRal8N-pmsYYIc',
#    'id': {'kind': 'youtube#video', 'videoId': 's48krRM0AqI'},
#    'snippet': {'publishedAt': '2021-08-05T03:23:31Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Want To Get Better At Surfing? Start Skating! | Bella Kenworthy',
#     'description': 'Ladybird Bella Kenworthy shows us that airs in a skatepark do in fact help your punts in the ocean. Catch her most recent performance in Vans Stab High, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/s48krRM0AqI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/s48krRM0AqI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/s48krRM0AqI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-05T03:23:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YG9_lUdpmmjny1l0aImcBcj5l9k',
#    'id': {'kind': 'youtube#video', 'videoId': 'HXv09HprQfM'},
#    'snippet': {'publishedAt': '2021-08-04T21:46:15Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Sky Brown And Sierra Kerr Battle It Out During The First Ever Ladybirds Final',
#     'description': "Olympic Skateboarding's Bronze Medalist Sky Brown and Sierra Kerr go head to head at the first-ever Ladybirds final during Vans Stab High Presented by ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HXv09HprQfM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HXv09HprQfM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HXv09HprQfM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-04T21:46:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'K_hlIQjJny7NlOjbn_XcgU5xnbA',
#    'id': {'kind': 'youtube#video', 'videoId': 'rQG2Oe-M7-c'},
#    'snippet': {'publishedAt': '2021-08-03T06:47:01Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'This Is How You Skate On A Surfboard | Jake Vincent In &#39;Yandina Speedway&#39;',
#     'description': "Jake Vincent's latest clip for Misfit Surfboards is loud, noisy and confusing. Similar to an exploding fireball from a leaking diesel engine, it may arrest your ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rQG2Oe-M7-c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rQG2Oe-M7-c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rQG2Oe-M7-c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-03T06:47:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mJ070JusSQDJ4nBUusJCytPtoyY',
#    'id': {'kind': 'youtube#video', 'videoId': '_P-ymEqpFeU'},
#    'snippet': {'publishedAt': '2021-08-03T05:07:48Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Electric Acid Surfboard Test: Mason And Coco Ho Test Every FCS Surf Fin You Can Imagine',
#     'description': 'How do you know which surfboard fin is right for you? You test them all.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_P-ymEqpFeU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_P-ymEqpFeU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_P-ymEqpFeU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-03T05:07:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '30dHm7m62J-dosm2nUlpYRJqR9U',
#    'id': {'kind': 'youtube#video', 'videoId': '-LPLNVKxd5k'},
#    'snippet': {'publishedAt': '2021-08-01T23:34:59Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Kelly Slater, Mason Ho, And More Score Perfect Barrels At Uluwatu',
#     'description': "The world's most entertaining surfers find shelter in perfect barrels at Uluwatu. Watch more from Red Bull No Contest here: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-LPLNVKxd5k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-LPLNVKxd5k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-LPLNVKxd5k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-01T23:34:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VbbmVVOCN85PrwnBcC9gCSUP7wA',
#    'id': {'kind': 'youtube#video', 'videoId': 'ta28mEcYuLM'},
#    'snippet': {'publishedAt': '2021-07-31T21:44:36Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Big Airs And Heavy Wipeouts While Surfing Costa Rica',
#     'description': "This wasn't an air contest, it was a war zone. Watch the heaviest of slams from Vans Stab High, Central America, presented by Monster Energy above.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ta28mEcYuLM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ta28mEcYuLM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ta28mEcYuLM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-31T21:44:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FGZu-K1EGytUV29hdZU2kUK9VDQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'LKidAMQVTv0'},
#    'snippet': {'publishedAt': '2021-07-30T23:37:03Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'DIY Skate Parks And Surfing In Jamaica With Shama Beckford',
#     'description': "Shama Beckford is one of Jamaica's leading talents, whether it be on a skateboard or on a surfboard. Watch his full profile video above.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LKidAMQVTv0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LKidAMQVTv0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LKidAMQVTv0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-30T23:37:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XUDsb7n5MRAmBvUXxMKKi3VB3vU',
#    'id': {'kind': 'youtube#video', 'videoId': 'u2BRlldXAaw'},
#    'snippet': {'publishedAt': '2021-07-30T01:56:18Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Vans Stab High Central America Presented by Monster Energy: Episode 2',
#     'description': 'With a lofty standard set by Mateus Herdy, our competitors will have to either go huge or counter the fixed height with a more tech-savvy approach. Given the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/u2BRlldXAaw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/u2BRlldXAaw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/u2BRlldXAaw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-30T01:56:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KPDaA3qzkMq9cIZFpR1OSX5djO0',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZNd8x-n0i20'},
#    'snippet': {'publishedAt': '2021-07-29T18:31:55Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'This Ladybird Surfs Similar To Dane Reynolds | Caity Simmers',
#     'description': "Don't believe us? Just ask Steph Gilmore, Nathan Fletcher, or Eric Geiselman. Watch Episode 1 of Vans Stab High, Central America, presented by Monster ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZNd8x-n0i20/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZNd8x-n0i20/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZNd8x-n0i20/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-29T18:31:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lUoCPjGFkQR52uwQ8tPf9QQnQVY',
#    'id': {'kind': 'youtube#video', 'videoId': '5g6jwL14JpY'},
#    'snippet': {'publishedAt': '2021-07-27T03:26:51Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Do You Know Where The Best Surf Wax In The World Is Made?',
#     'description': "Kelly Slater, Dane Reynolds, John John Florence, and most Brazilian CT surfers will agree that Fu is the best wax in the world, but do they know how it's made?",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5g6jwL14JpY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5g6jwL14JpY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5g6jwL14JpY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-27T03:26:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FVCObDBw-TG_UAdSWNY4QXuleWw',
#    'id': {'kind': 'youtube#video', 'videoId': 'zzGpun3CYaA'},
#    'snippet': {'publishedAt': '2021-07-25T05:32:01Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Is This The Best Air Ever Done By A Female Surfer? | Erin Brooks',
#     'description': 'No jet ski need, this Ladybird can set the bar on her own. Watch the full episode of Vans Stab High, Central America, presented by Monster Energy here: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zzGpun3CYaA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zzGpun3CYaA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zzGpun3CYaA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-25T05:32:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jcRCzzol41hT8bTJ2FRH6x7OWiY',
#    'id': {'kind': 'youtube#video', 'videoId': 'LqKVqCA8RBA'},
#    'snippet': {'publishedAt': '2021-07-23T04:12:37Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Vans Stab High Central America Presented by Monster Energy: Episode 1',
#     'description': "Whats happens when you bring over 20 of the world's best aerial surfers to a pumping beach break? You're about to find out. Welcome to Episode 1 of Vans ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LqKVqCA8RBA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LqKVqCA8RBA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LqKVqCA8RBA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-23T04:12:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vpeMiRYTlJofu_C8PZC0s9xVDLk',
#    'id': {'kind': 'youtube#video', 'videoId': 'RHQ3w5MXd4E'},
#    'snippet': {'publishedAt': '2021-07-22T23:37:59Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Indonesia Has High Hopes For The Olympics | Rio Waida',
#     'description': "Rio Waida's dream has always been to qualify for the CT, but for now, he's on the hunt for an Olympic Gold Medal. Filmed and edited by Ryan Williams ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RHQ3w5MXd4E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RHQ3w5MXd4E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RHQ3w5MXd4E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-22T23:37:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QlOaaKAVEBistijrHBLQNjAJNus',
#    'id': {'kind': 'youtube#video', 'videoId': '2-DWp1SVsls'},
#    'snippet': {'publishedAt': '2021-07-22T06:30:07Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': 'Surf or Skate? Oscar Berry Chooses Both',
#     'description': "There's only a handful of surfers who excel in more than one sport. Oscar Berry is one of them. Equally gifted riding waves and trucking concrete, he joins the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2-DWp1SVsls/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2-DWp1SVsls/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2-DWp1SVsls/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-22T06:30:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'f5KJsVaBQLj36c9MfclIRMcdpx0',
#    'id': {'kind': 'youtube#video', 'videoId': '5hgVSjzvDBA'},
#    'snippet': {'publishedAt': '2021-07-21T17:39:07Z',
#     'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#     'title': '&quot;One Goal: Go As High As Humanly Possible And Ride Away Clean&quot;',
#     'description': 'Episode 1 of Vans Stab High Central America, presented by Monster Energy premieres this Thursday at 7 PM PST right here on Youtube. Click here to learn ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5hgVSjzvDBA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5hgVSjzvDBA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5hgVSjzvDBA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Stab: We like to surf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-21T17:39:07Z'}}]}

# %%
print(f"We retrieved {len(response['items'])} videos")
response['items']
# Out:
# We retrieved 50 videos
# [{'kind': 'youtube#searchResult',
#   'etag': 'RMAyq97JwQAMlOqsySJrIR_VJOY',
#   'id': {'kind': 'youtube#video', 'videoId': 'R4mebR724Pg'},
#   'snippet': {'publishedAt': '2021-09-17T21:47:42Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Mason Ho&#39;s 4 Favorite Electric Acid Boards REVEALED',
#    'description': 'With ten Electric Acid Surfboards in his quiver, Mason has to decide which four boards he will hold onto.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-17T21:47:42Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'HFzuqyenyypw_V3aCqKB5gmMAtk',
#   'id': {'kind': 'youtube#video', 'videoId': 'RF_w8EQVFnY'},
#   'snippet': {'publishedAt': '2021-09-16T20:45:56Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Kolohe Andino vs Griffin Colapinto vs Ian Crane In A Hometown Showdown | Surf100 Lower Trestles',
#    'description': 'Inside 100-minute wave riding expo at Lower Trestles with Kolohe Andino, Griffin Colapinto, and Ian Crane. The full show is anchored with the no-holds-barred ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RF_w8EQVFnY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/RF_w8EQVFnY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/RF_w8EQVFnY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-16T20:45:56Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '79cwQPiSYAfmTjssY6DZFFbBwfs',
#   'id': {'kind': 'youtube#video', 'videoId': 'LUdqckbhzwY'},
#   'snippet': {'publishedAt': '2021-09-13T21:53:44Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'A 100% Authentic New Zealand Surf Film | &#39;Bro Town&#39;',
#    'description': 'When it comes to New Zealand, local boys Elliot Paerata Reid, Kehu Butler, Ware Wano, and Dune Kennings know exactly when to be, where to be, and how ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LUdqckbhzwY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LUdqckbhzwY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LUdqckbhzwY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-13T21:53:44Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'YBNj-W6BW1Ms3iT7IgwiWCls2ac',
#   'id': {'kind': 'youtube#video', 'videoId': '9rd31N1EOwQ'},
#   'snippet': {'publishedAt': '2021-09-12T17:59:39Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Dane Reynolds, Mason Ho, And Mikey February Face-off At Surf100 Mexico',
#    'description': 'Surf100 is a wave riding exposition that takes place over a single, 100-minute period and is judged live, at a later date, by the internet. In this edition, Dane ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9rd31N1EOwQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9rd31N1EOwQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9rd31N1EOwQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-12T17:59:39Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'w3cZBOqBRJjGRfdKh3ddp4H85Vg',
#   'id': {'kind': 'youtube#video', 'videoId': 'w6CTQfDjW9o'},
#   'snippet': {'publishedAt': '2021-09-11T12:53:13Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'More Raw Footage Of The WSL Finalists Warming Up At Lowers | 9/7/21',
#    'description': 'Another day, another Lowers session with world title contenders scrapping for every bit of warm-up they can get. Watch the best clips of Gabriel Medina, Connor ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w6CTQfDjW9o/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/w6CTQfDjW9o/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/w6CTQfDjW9o/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-11T12:53:13Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'X6CuhGhiOmdMV0n96n-2fQooRkc',
#   'id': {'kind': 'youtube#video', 'videoId': 'LURSOgoQGgI'},
#   'snippet': {'publishedAt': '2021-09-10T14:53:12Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'South African Charger Beyrick De Vries Is Ready For The Upcoming Challenger Series | DBN',
#    'description': 'Unlike other CT hopefuls from nations that invest more in surfing, Beyrick has not had the luxury of financial freedom, government-subsidized athlete ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LURSOgoQGgI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LURSOgoQGgI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LURSOgoQGgI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-10T14:53:12Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '9arHTqoXJo8G3hLmaGsL-NqVwaU',
#   'id': {'kind': 'youtube#video', 'videoId': 'CmmoJk2nj60'},
#   'snippet': {'publishedAt': '2021-09-09T20:16:27Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Chippa Wilson And The Adelio Team Hit Every Ramp In Sight | Solace',
#    'description': "Chippa Wilson, Koby Perkovich, Robbie Rickard, and Ethan Solberg launch air after air in the Adelio Team's latest edit 'Solace.' Filmed by Dan Scott and ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CmmoJk2nj60/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/CmmoJk2nj60/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/CmmoJk2nj60/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-09T20:16:27Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '-6k5uWKmw3tjDiziV76B7PyaItA',
#   'id': {'kind': 'youtube#video', 'videoId': 'wd2JDFpj31w'},
#   'snippet': {'publishedAt': '2021-09-09T03:19:47Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Total Backhand Control With Gatien Delahaye | Pitstops',
#    'description': 'From the Caribbean island of Guadeloupe, the 24-year-old Gatien Delahaye has developed total control on his backhand. His timing is near perfect, his body ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wd2JDFpj31w/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wd2JDFpj31w/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wd2JDFpj31w/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-09T03:19:47Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'hZkAXiTuxzlvhMdRTRrgx613SSg',
#   'id': {'kind': 'youtube#video', 'videoId': 'yO_216d6Esc'},
#   'snippet': {'publishedAt': '2021-09-08T05:47:26Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Slip, Slide And Sabotage | S.U.R.F. Episode 4 Frictionless',
#    'description': 'In the fourth and final episode of S.U.R.F. we will be crowning our winner of the inaugural Stab X Byron Bay Brewery TV show. The theme of this challenge is ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yO_216d6Esc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/yO_216d6Esc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/yO_216d6Esc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-08T05:47:26Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ZgcKd75RmVIbUV9DBiHfRqPsgk0',
#   'id': {'kind': 'youtube#video', 'videoId': 'L0h2Ne_408c'},
#   'snippet': {'publishedAt': '2021-09-08T03:10:10Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'All-Star Crew Surfs Lowers Before The WSL Finals | Raw Clips 9/6/21',
#    'description': 'Based on the swell forecast, it looks like the WSL Finals will run sometime between Sunday, Sept. 12th, and Tuesday, Sept. 14th. For now, we can offer you 15 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L0h2Ne_408c/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/L0h2Ne_408c/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/L0h2Ne_408c/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-08T03:10:10Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Ktom-cmeoc9mrzAWhQDJUwOVFn4',
#   'id': {'kind': 'youtube#video', 'videoId': 'MO2d3F1OZDg'},
#   'snippet': {'publishedAt': '2021-09-06T01:42:57Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'A Full Review Of The ACSOD Monster | Joyride Board Test',
#    'description': "Alex Crews has been shaping out of the Gold Coast for the past decade. In recent years, he's refined his craft and is now consistently putting quality boards ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MO2d3F1OZDg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/MO2d3F1OZDg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/MO2d3F1OZDg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-06T01:42:57Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '0-LMr46Ow6BXAvZaLE-7d8P2wWY',
#   'id': {'kind': 'youtube#video', 'videoId': 'i-t64DlVjR0'},
#   'snippet': {'publishedAt': '2021-09-03T22:00:02Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'A Test Run Of Six Used Surfboards | Off The Rack Surfboard Broker',
#    'description': "In this edition of Off The Rack, Schuyler Allen teams up with North Shore's smooth operator and backflip pioneer, Flynn Novak, and put Surfboard Broker's ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i-t64DlVjR0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/i-t64DlVjR0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/i-t64DlVjR0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-03T22:00:02Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'v1z9nO7BKXelG3HP5RnG57-JPFQ',
#   'id': {'kind': 'youtube#video', 'videoId': '_8p7O5fc4Sc'},
#   'snippet': {'publishedAt': '2021-09-02T18:16:15Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'This John Florence Doppelgänger Can Surf | Brodi Sale &#39;Live In The Moment&#39;',
#    'description': "When flying down the face of a wave, it's easy to mistake Brodi Sale for John Florence. The curly blonde hair, athletic stature, and amount of drive are noticeably ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_8p7O5fc4Sc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_8p7O5fc4Sc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_8p7O5fc4Sc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-02T18:16:15Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'syOyAzkQ0qWmJolaRSFvNtYIpAA',
#   'id': {'kind': 'youtube#video', 'videoId': 'IXPxlHhqp-A'},
#   'snippet': {'publishedAt': '2021-09-02T15:12:58Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Dead Kooks Shaper Profile | E.A.S.T. With Mason and Coco Ho',
#    'description': 'Eden Saul, the man behind Dead Kooks surfboards, has spent his career cranking out mesmerizing alternative surfboards. For this reason, we invited him to ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IXPxlHhqp-A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/IXPxlHhqp-A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/IXPxlHhqp-A/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-02T15:12:58Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '2gSow2-iNxHhDcPmXptpL43MPow',
#   'id': {'kind': 'youtube#video', 'videoId': 'jMBxalU1d2w'},
#   'snippet': {'publishedAt': '2021-09-01T00:35:25Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Everything You Need To Know About &#39;The Ultimate Surfer&#39; Wave Pool',
#    'description': "Take an inside look at Kelly Slater's Surf Ranch, which hosted the reality TV show 'The Ultimate Surfer'. Read our episode 3 recap here: ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jMBxalU1d2w/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/jMBxalU1d2w/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/jMBxalU1d2w/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-01T00:35:25Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ASUN40l4EvLYDTmqOiy9jEHepmk',
#   'id': {'kind': 'youtube#video', 'videoId': 'JoPtBBqVfbM'},
#   'snippet': {'publishedAt': '2021-08-31T10:14:26Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Two Broken Surfboards GLUED Together?! |S.U.R.F Episode 3 Resourcefulness',
#    'description': "Resourcefulness: the ability to find quick and clever ways to overcome difficulties. In episode 3 of S.U.R.F., Ozzy Wright, Jake Vincent, Ari 'Krooky' Browne, and ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JoPtBBqVfbM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/JoPtBBqVfbM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/JoPtBBqVfbM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-31T10:14:26Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Z7da1ACVwNNA3WuKIDd2ja9dB1Q',
#   'id': {'kind': 'youtube#video', 'videoId': 'xGrxuydv2nY'},
#   'snippet': {'publishedAt': '2021-08-29T23:14:26Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Testing The Haydenshapes Cohort_I During A Solid East Coast Swell',
#    'description': 'My first impression of The Haydenshapes Cohort_I was that it had a good amount of entry rocker. The beak flips up aggressively in the last eight inches, which ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xGrxuydv2nY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/xGrxuydv2nY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/xGrxuydv2nY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-29T23:14:26Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'k_1M5XCpyKFQCqvmBeZjqAytw8Q',
#   'id': {'kind': 'youtube#video', 'videoId': 'MZhMAXjYE6k'},
#   'snippet': {'publishedAt': '2021-08-27T20:58:28Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Are Alternative Surfboards Just A Trend? | Surf100 Mexico',
#    'description': 'Over time boards have gotten smaller, wider, and in some cases softer. All these changes, whether slight or severe, have been a direct response to consumer ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MZhMAXjYE6k/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/MZhMAXjYE6k/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/MZhMAXjYE6k/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-27T20:58:28Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'LLX3u3a6oqVPqc_KuGN-ZoY0XtE',
#   'id': {'kind': 'youtube#video', 'videoId': '8CK6moGEvRA'},
#   'snippet': {'publishedAt': '2021-08-25T21:02:57Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'The Best Independent Surf Film You&#39;ll Watch This Week | &#39;Thunderbird&#39; By Colin Moran',
#    'description': 'Colin Moran, Chippa Wilson, Alex Knost, Andrew Doheny, Balaram Stack, Danny Fuller, Christian and Greyson Fletcher, Makua Rothman, and Ford Archbold ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8CK6moGEvRA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/8CK6moGEvRA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/8CK6moGEvRA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-25T21:02:57Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'AqBK5t2GeEvfWXj7SbJwJ3sqePY',
#   'id': {'kind': 'youtube#video', 'videoId': 'df6K0AAJ-y4'},
#   'snippet': {'publishedAt': '2021-08-25T02:13:25Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Rainbows In The Rearview | A Surf Film By Albee Layer',
#    'description': "Albee Layer fits no mold. Let's start by scratching comp guy off the list. According to the WSL's website, he's competed in only one non big-wave event since ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/df6K0AAJ-y4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/df6K0AAJ-y4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/df6K0AAJ-y4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-25T02:13:25Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '-Uh8X9YOF-uZ3S1_2NOsdjEnfMw',
#   'id': {'kind': 'youtube#video', 'videoId': '4erx2fu0V9k'},
#   'snippet': {'publishedAt': '2021-08-24T06:07:14Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Could You Perform Like This On A Board From The Late 1900s?  S.U.R.F. Episode 2',
#    'description': "How well can you surf a board that costs 24 beers and $100? | S.U.R.F. Ep. 2 'Uncover' Brought to you by Stab and Byron Bay Brewery, the show features four of ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4erx2fu0V9k/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4erx2fu0V9k/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4erx2fu0V9k/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-24T06:07:14Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Zm1jGihnS1x2SjCer8XaiuxR2Yo',
#   'id': {'kind': 'youtube#video', 'videoId': '3u3ftJUHiuQ'},
#   'snippet': {'publishedAt': '2021-08-22T12:00:04Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Wait, This Board Has A Mechanical SPRING Inside?',
#    'description': "The Campbell Designed Chunky Toe features a mechanical spring in place of its stringer. What is a mechanical spring? We have no idea, and they won't tell us ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3u3ftJUHiuQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/3u3ftJUHiuQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/3u3ftJUHiuQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-22T12:00:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'OzATh5QlCAzbrDfiRn8E6xDTrW0',
#   'id': {'kind': 'youtube#video', 'videoId': 'JfMZebb8ETc'},
#   'snippet': {'publishedAt': '2021-08-20T13:43:17Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'The Best 11-Year-Old Tube Rider On EARTH',
#    'description': "Meet Dylan Wilcoxen, lifetime Kanui Resort resident and the most adept pre-teen barrel rider we've ever seen. He also likes twin fins, fishing, and ice pops.",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JfMZebb8ETc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/JfMZebb8ETc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/JfMZebb8ETc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-20T13:43:17Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'PFHTFNzQjZuQqudhBTFxvP7KKBg',
#   'id': {'kind': 'youtube#video', 'videoId': 'uMRPTkhgpVE'},
#   'snippet': {'publishedAt': '2021-08-19T06:05:08Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Stylish Laybacks And Punk Rock Tap Dancing With Jaleesa Vincent',
#    'description': "Laced with spook, stylish frontside laybacks, fine embroidery, joyous tap dancing, love songs, and dark biblical themes, Jaleesa Vincent's 9-minute clip is a ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uMRPTkhgpVE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/uMRPTkhgpVE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/uMRPTkhgpVE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-19T06:05:08Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '3blzUu2AEvTkZhyjzlP8eaMJ2do',
#   'id': {'kind': 'youtube#video', 'videoId': 'HEVbfDucd6A'},
#   'snippet': {'publishedAt': '2021-08-17T18:58:23Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'This Wave Looks Identical To Pipeline',
#    'description': 'Manuel Lezcano is a surfer from the Canary Islands that knows exactly where to be, and when. There are moments where everything lines up perfectly, and the ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HEVbfDucd6A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/HEVbfDucd6A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/HEVbfDucd6A/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-17T18:58:23Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'fl3RbGN4cW2RBPlIJGFioBvXTIw',
#   'id': {'kind': 'youtube#video', 'videoId': 'F-Z45G9VgVc'},
#   'snippet': {'publishedAt': '2021-08-17T01:45:03Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': '4 Men Compete to surf the LONGEST wave | S.U.R.F. Ep. 1 &#39;Space&#39;',
#    'description': "Introducing S.U.R.F: a new medium-performance, four-part Stab TV show. Brought to you by Stab and Byron Bay Brewery, the show features four of Byron's most ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F-Z45G9VgVc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/F-Z45G9VgVc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/F-Z45G9VgVc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-17T01:45:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'tr6P5XRZGr-ki8ApzPX1cfjZg90',
#   'id': {'kind': 'youtube#video', 'videoId': 'ITMS5eOIuYI'},
#   'snippet': {'publishedAt': '2021-08-15T01:40:00Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'What Happens When A World-Class High Performance Shaper Tries A Mid-Length With Harrison Roach?',
#    'description': "There are many ways one could surf a midlength, but Harrison Roach's approach is relatively unmatched. Watch his stroll on the JS Big Baron above.",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ITMS5eOIuYI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ITMS5eOIuYI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ITMS5eOIuYI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-15T01:40:00Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '-SGcN4CxcqTcyrGNjNZ3CWfvaNo',
#   'id': {'kind': 'youtube#video', 'videoId': '5UYS4BvtDPY'},
#   'snippet': {'publishedAt': '2021-08-13T22:43:44Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Introducing S.U.R.F: A Medium-Performance Surf Contest',
#    'description': "Brought to you by Stab and Byron Bay Brewery, the show features four of Byron's most colourful and irreverent surfers, competing in four unique challenges, ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5UYS4BvtDPY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5UYS4BvtDPY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5UYS4BvtDPY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-13T22:43:44Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'RBKoepTFRFw9hgKsLefhbqBpXs4',
#   'id': {'kind': 'youtube#video', 'videoId': 'D8REk6H4Cck'},
#   'snippet': {'publishedAt': '2021-08-13T02:55:02Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'FINAL: Vans Stab High, Central America, Presented by Monster Energy: Episode 5',
#    'description': "Welcome to the Vans Stab High, Central America, Presented by Monster Energy final. It's time for our Stab Premium audience to choose this year's winner.",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D8REk6H4Cck/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/D8REk6H4Cck/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/D8REk6H4Cck/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-13T02:55:02Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'N_F5Zv1vB2TncVgLXPX1y7leu1s',
#   'id': {'kind': 'youtube#video', 'videoId': '_y2Xg-I50eU'},
#   'snippet': {'publishedAt': '2021-08-12T02:48:50Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Taking The Stab in the Dark Winning Board For a Joyride | Sharpeye Inferno72',
#    'description': 'Does anyone else notice the amount of Sharpeye surfboards in rotation at the Corona Open Mexico? There seems to be a new favorite board brand amongst ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_y2Xg-I50eU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_y2Xg-I50eU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_y2Xg-I50eU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-12T02:48:50Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'pvNWSYUJXBd62kqRADOHOY6S3kk',
#   'id': {'kind': 'youtube#video', 'videoId': 'TFJFzDiNvnc'},
#   'snippet': {'publishedAt': '2021-08-11T01:53:55Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Vans Stab High, Central America, Presented by Monster Energy: Episode 4',
#    'description': "Enough giggling and Imperials, it's time to narrow the playing field. Episode 4 of Vans Stab High, Central America, presented by Monster Energy, follows our ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TFJFzDiNvnc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/TFJFzDiNvnc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/TFJFzDiNvnc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-11T01:53:55Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '5iiPZChPWZki7tJeWnugc9uMY1E',
#   'id': {'kind': 'youtube#video', 'videoId': 'GwxpMoFnNww'},
#   'snippet': {'publishedAt': '2021-08-10T16:50:15Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Did A Plumber Just Stomp A Full Rotation ? | Jai Walsh In &#39;Labyrinth&#39;',
#    'description': "The ongoing joke is that 'Labyrinth' is Jai's 'retirement clip'. When you work for cash as a plumber and surf for fun then trying to do your best surfing in front of a ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GwxpMoFnNww/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/GwxpMoFnNww/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/GwxpMoFnNww/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-10T16:50:15Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'iuH3FFLH2F_tYRqdlB2D1_1zcZk',
#   'id': {'kind': 'youtube#video', 'videoId': 'eO2Ws1Rukd0'},
#   'snippet': {'publishedAt': '2021-08-09T20:04:15Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Stab’s Search For The World&#39;s Best Wetsuit',
#    'description': 'That ice-cold water will be here before you know it, watch above to see which wetsuit will give you the most bang for your buck. Wetsuits tested (All 3/2 wetsuits): ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eO2Ws1Rukd0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/eO2Ws1Rukd0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/eO2Ws1Rukd0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-09T20:04:15Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '0E4Gqc2CpC_pZsR1zXEESPxNiow',
#   'id': {'kind': 'youtube#video', 'videoId': 'zk26PAQK45A'},
#   'snippet': {'publishedAt': '2021-08-07T04:55:42Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'XXL Waves At Teahupoo With Nathan Florence, Jack Robinson, And More',
#    'description': "The world's best big wave surfers including Nathan Florence, Lucas Chumbo, and more pull into massive bombs at Teahupoo in Tahiti. Watch More from Red ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zk26PAQK45A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zk26PAQK45A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zk26PAQK45A/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-07T04:55:42Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'mLGDmKyJgUXKtFwVPQt8AxsBBJg',
#   'id': {'kind': 'youtube#video', 'videoId': '0PtXWSmaJn4'},
#   'snippet': {'publishedAt': '2021-08-06T03:29:28Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Vans Stab High, Central America, Presented by Monster Energy: Episode 3',
#    'description': 'What exactly defines a Ladybird? According to our guest narrator, Coco Ho, “A ladybird is a 17 and under female surfer with an affinity for flight.” Sierra Kerr won ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0PtXWSmaJn4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/0PtXWSmaJn4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/0PtXWSmaJn4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-06T03:29:28Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '6ETcNRPopb8ccNRal8N-pmsYYIc',
#   'id': {'kind': 'youtube#video', 'videoId': 's48krRM0AqI'},
#   'snippet': {'publishedAt': '2021-08-05T03:23:31Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Want To Get Better At Surfing? Start Skating! | Bella Kenworthy',
#    'description': 'Ladybird Bella Kenworthy shows us that airs in a skatepark do in fact help your punts in the ocean. Catch her most recent performance in Vans Stab High, ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/s48krRM0AqI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/s48krRM0AqI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/s48krRM0AqI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-05T03:23:31Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'YG9_lUdpmmjny1l0aImcBcj5l9k',
#   'id': {'kind': 'youtube#video', 'videoId': 'HXv09HprQfM'},
#   'snippet': {'publishedAt': '2021-08-04T21:46:15Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Sky Brown And Sierra Kerr Battle It Out During The First Ever Ladybirds Final',
#    'description': "Olympic Skateboarding's Bronze Medalist Sky Brown and Sierra Kerr go head to head at the first-ever Ladybirds final during Vans Stab High Presented by ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HXv09HprQfM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/HXv09HprQfM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/HXv09HprQfM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-04T21:46:15Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'K_hlIQjJny7NlOjbn_XcgU5xnbA',
#   'id': {'kind': 'youtube#video', 'videoId': 'rQG2Oe-M7-c'},
#   'snippet': {'publishedAt': '2021-08-03T06:47:01Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'This Is How You Skate On A Surfboard | Jake Vincent In &#39;Yandina Speedway&#39;',
#    'description': "Jake Vincent's latest clip for Misfit Surfboards is loud, noisy and confusing. Similar to an exploding fireball from a leaking diesel engine, it may arrest your ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rQG2Oe-M7-c/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/rQG2Oe-M7-c/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/rQG2Oe-M7-c/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-03T06:47:01Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'mJ070JusSQDJ4nBUusJCytPtoyY',
#   'id': {'kind': 'youtube#video', 'videoId': '_P-ymEqpFeU'},
#   'snippet': {'publishedAt': '2021-08-03T05:07:48Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Electric Acid Surfboard Test: Mason And Coco Ho Test Every FCS Surf Fin You Can Imagine',
#    'description': 'How do you know which surfboard fin is right for you? You test them all.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_P-ymEqpFeU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_P-ymEqpFeU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_P-ymEqpFeU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-03T05:07:48Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '30dHm7m62J-dosm2nUlpYRJqR9U',
#   'id': {'kind': 'youtube#video', 'videoId': '-LPLNVKxd5k'},
#   'snippet': {'publishedAt': '2021-08-01T23:34:59Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Kelly Slater, Mason Ho, And More Score Perfect Barrels At Uluwatu',
#    'description': "The world's most entertaining surfers find shelter in perfect barrels at Uluwatu. Watch more from Red Bull No Contest here: ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-LPLNVKxd5k/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/-LPLNVKxd5k/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/-LPLNVKxd5k/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-01T23:34:59Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'VbbmVVOCN85PrwnBcC9gCSUP7wA',
#   'id': {'kind': 'youtube#video', 'videoId': 'ta28mEcYuLM'},
#   'snippet': {'publishedAt': '2021-07-31T21:44:36Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Big Airs And Heavy Wipeouts While Surfing Costa Rica',
#    'description': "This wasn't an air contest, it was a war zone. Watch the heaviest of slams from Vans Stab High, Central America, presented by Monster Energy above.",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ta28mEcYuLM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ta28mEcYuLM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ta28mEcYuLM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-31T21:44:36Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'FGZu-K1EGytUV29hdZU2kUK9VDQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'LKidAMQVTv0'},
#   'snippet': {'publishedAt': '2021-07-30T23:37:03Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'DIY Skate Parks And Surfing In Jamaica With Shama Beckford',
#    'description': "Shama Beckford is one of Jamaica's leading talents, whether it be on a skateboard or on a surfboard. Watch his full profile video above.",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LKidAMQVTv0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LKidAMQVTv0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LKidAMQVTv0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-30T23:37:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'XUDsb7n5MRAmBvUXxMKKi3VB3vU',
#   'id': {'kind': 'youtube#video', 'videoId': 'u2BRlldXAaw'},
#   'snippet': {'publishedAt': '2021-07-30T01:56:18Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Vans Stab High Central America Presented by Monster Energy: Episode 2',
#    'description': 'With a lofty standard set by Mateus Herdy, our competitors will have to either go huge or counter the fixed height with a more tech-savvy approach. Given the ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/u2BRlldXAaw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/u2BRlldXAaw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/u2BRlldXAaw/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-30T01:56:18Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'KPDaA3qzkMq9cIZFpR1OSX5djO0',
#   'id': {'kind': 'youtube#video', 'videoId': 'ZNd8x-n0i20'},
#   'snippet': {'publishedAt': '2021-07-29T18:31:55Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'This Ladybird Surfs Similar To Dane Reynolds | Caity Simmers',
#    'description': "Don't believe us? Just ask Steph Gilmore, Nathan Fletcher, or Eric Geiselman. Watch Episode 1 of Vans Stab High, Central America, presented by Monster ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZNd8x-n0i20/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ZNd8x-n0i20/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ZNd8x-n0i20/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-29T18:31:55Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'lUoCPjGFkQR52uwQ8tPf9QQnQVY',
#   'id': {'kind': 'youtube#video', 'videoId': '5g6jwL14JpY'},
#   'snippet': {'publishedAt': '2021-07-27T03:26:51Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Do You Know Where The Best Surf Wax In The World Is Made?',
#    'description': "Kelly Slater, Dane Reynolds, John John Florence, and most Brazilian CT surfers will agree that Fu is the best wax in the world, but do they know how it's made?",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5g6jwL14JpY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5g6jwL14JpY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5g6jwL14JpY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-27T03:26:51Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'FVCObDBw-TG_UAdSWNY4QXuleWw',
#   'id': {'kind': 'youtube#video', 'videoId': 'zzGpun3CYaA'},
#   'snippet': {'publishedAt': '2021-07-25T05:32:01Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Is This The Best Air Ever Done By A Female Surfer? | Erin Brooks',
#    'description': 'No jet ski need, this Ladybird can set the bar on her own. Watch the full episode of Vans Stab High, Central America, presented by Monster Energy here: ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zzGpun3CYaA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zzGpun3CYaA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zzGpun3CYaA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-25T05:32:01Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'jcRCzzol41hT8bTJ2FRH6x7OWiY',
#   'id': {'kind': 'youtube#video', 'videoId': 'LqKVqCA8RBA'},
#   'snippet': {'publishedAt': '2021-07-23T04:12:37Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Vans Stab High Central America Presented by Monster Energy: Episode 1',
#    'description': "Whats happens when you bring over 20 of the world's best aerial surfers to a pumping beach break? You're about to find out. Welcome to Episode 1 of Vans ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LqKVqCA8RBA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LqKVqCA8RBA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LqKVqCA8RBA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-23T04:12:37Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'vpeMiRYTlJofu_C8PZC0s9xVDLk',
#   'id': {'kind': 'youtube#video', 'videoId': 'RHQ3w5MXd4E'},
#   'snippet': {'publishedAt': '2021-07-22T23:37:59Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Indonesia Has High Hopes For The Olympics | Rio Waida',
#    'description': "Rio Waida's dream has always been to qualify for the CT, but for now, he's on the hunt for an Olympic Gold Medal. Filmed and edited by Ryan Williams ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RHQ3w5MXd4E/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/RHQ3w5MXd4E/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/RHQ3w5MXd4E/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-22T23:37:59Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'QlOaaKAVEBistijrHBLQNjAJNus',
#   'id': {'kind': 'youtube#video', 'videoId': '2-DWp1SVsls'},
#   'snippet': {'publishedAt': '2021-07-22T06:30:07Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': 'Surf or Skate? Oscar Berry Chooses Both',
#    'description': "There's only a handful of surfers who excel in more than one sport. Oscar Berry is one of them. Equally gifted riding waves and trucking concrete, he joins the ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2-DWp1SVsls/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/2-DWp1SVsls/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/2-DWp1SVsls/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-22T06:30:07Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'f5KJsVaBQLj36c9MfclIRMcdpx0',
#   'id': {'kind': 'youtube#video', 'videoId': '5hgVSjzvDBA'},
#   'snippet': {'publishedAt': '2021-07-21T17:39:07Z',
#    'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#    'title': '&quot;One Goal: Go As High As Humanly Possible And Ride Away Clean&quot;',
#    'description': 'Episode 1 of Vans Stab High Central America, presented by Monster Energy premieres this Thursday at 7 PM PST right here on Youtube. Click here to learn ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5hgVSjzvDBA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5hgVSjzvDBA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5hgVSjzvDBA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Stab: We like to surf',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-21T17:39:07Z'}}]

# %%
# To get info from a single video
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'RMAyq97JwQAMlOqsySJrIR_VJOY',
#  'id': {'kind': 'youtube#video', 'videoId': 'R4mebR724Pg'},
#  'snippet': {'publishedAt': '2021-09-17T21:47:42Z',
#   'channelId': 'UCsG5dkqFUHZO6eY9uOzQqow',
#   'title': 'Mason Ho&#39;s 4 Favorite Electric Acid Boards REVEALED',
#   'description': 'With ten Electric Acid Surfboards in his quiver, Mason has to decide which four boards he will hold onto.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/R4mebR724Pg/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Stab: We like to surf',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2021-09-17T21:47:42Z'}}

# %% [markdown]
# # Parsing through the videos and store specific information

# %%
video_id = response['items'][0]['id']['videoId']
video_title = str(response['items'][0]['snippet']['title']).replace('&', ' ')
# to grab just the timestamp we can split on the 'T'
upload_date = str(response['items'][0]['snippet']['publishedAt']).split('T')[0]
print("Video ID: {}\nVideo Title: {}\nUpload Date: {}".format(video_id,video_title,upload_date))
# Out:
# Video ID: R4mebR724Pg
# Video Title: Mason Ho #39;s 4 Favorite Electric Acid Boards REVEALED
# Upload Date: 2021-09-17

# %% [markdown]
# ## Creating the Loop

# %%
# we just want to look at videos, so we add the following parameter:
# 'kind':'youtube#video'
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = str(video['snippet']['title']).replace('&', ' ')
        # to grab just the timestamp we can split on the 'T'
        upload_date = str(video['snippet']['publishedAt']).split('T')[0]

# %% [markdown]
# # Making a second API call using the retrieved ´video_id´
# ## Other Metrics we want to retrieve from the API
# - Video ID
# - Video Title
# - Publish Data
# ## Specific video metrics:
# - View count
# - Link count
# - Dislike Count
# - Comment Count

# %%
new_search_params = "videos?key=" + API_KEY + "&id=" + video_id + "&part=statistics"
new_url = root_url + new_search_params

# %%
response_video_stats = requests.get(new_url).json()
response_video_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'P95iJUX9-e5BhSQ-6Jnt2NkLEL4',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'JR3LiFBLJPcJeYrmhWf0tRI3kD8',
#    'id': '5hgVSjzvDBA',
#    'statistics': {'viewCount': '9604',
#     'likeCount': '92',
#     'dislikeCount': '14',
#     'favoriteCount': '0',
#     'commentCount': '4'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
view_count = response_video_stats['items'][0]['statistics']['viewCount']
like_count = response_video_stats['items'][0]['statistics']['likeCount']
dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
comment_count = response_video_stats['items'][0]['statistics']['commentCount']
print("Video Count: {}\nLike Count: {}\nDislike Count: {}\nComment Count: {}".format(view_count,like_count,dislike_count,comment_count))
# Out:
# Video Count: 9604
# Like Count: 92
# Dislike Count: 14
# Comment Count: 4

# %% [markdown]
# ## Create the Full loop

# %%
df = pd.DataFrame()
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = str(video['snippet']['title']).replace('&', ' ')
        # to grab just the timestamp we can split on the 'T'
        upload_date = str(video['snippet']['publishedAt']).split('T')[0]

         #colleccting view, like, dislike, comment counts
        new_search_params = "videos?key=" + API_KEY + "&id=" + video_id + "&part=statistics"
        new_url = root_url + new_search_params

        response_video_stats = requests.get(new_url).json()

        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
        try: 
            comment_count = response_video_stats['items'][0]['statistics']['commentCount']
        except KeyError:
            comment_count = 0
        
        video_data = {'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date,
                      'view_count':view_count, 'like_count':like_count, 'dislike_count':dislike_count,
                      'comment_count':comment_count}

        df = df.append(video_data, ignore_index=True)

# %%
df.head()
# Out:
#   comment_count dislike_count like_count upload_date     video_id  \
# 0            10             5        365  2021-09-17  R4mebR724Pg
# 1            10             7        235  2021-09-16  RF_w8EQVFnY
# 2            81            11       1024  2021-09-13  LUdqckbhzwY
# 3            37            22        751  2021-09-12  9rd31N1EOwQ
# 4           104             6        476  2021-09-11  w6CTQfDjW9o
#
#                                          video_title view_count
# 0  Mason Ho #39;s 4 Favorite Electric Acid Boards...      19837
# 1  Kolohe Andino vs Griffin Colapinto vs Ian Cran...      17249
# 2  A 100% Authentic New Zealand Surf Film |  #39;...      34806
# 3  Dane Reynolds, Mason Ho, And Mikey February Fa...      51184
# 4  More Raw Footage Of The WSL Finalists Warming ...      39312

# %% [markdown]
# # Improving the Code

# %%
def get_video_details(video_id):
    new_search_params = "videos?key=" + API_KEY + "&id=" + video_id + "&part=statistics"
    new_url = root_url + new_search_params

    response = requests.get(new_url).json()

    view_count = response['items'][0]['statistics']['viewCount']
    like_count = response['items'][0]['statistics']['likeCount']
    dislike_count = response['items'][0]['statistics']['dislikeCount']
    try: 
        comment_count = response['items'][0]['statistics']['commentCount']
    except KeyError:
        comment_count = 0
    
    return view_count, like_count, dislike_count, comment_count

# %%
def get_videos():
    page_token = ""
    while 1:
        # Create URL
        url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+Channel_id+"&part=snippet,id&order=date&maxResults=10000&"+ page_token
        records = []

        response = requests.get(url).json()
        # Wait 1 second before starting the loop
        time.sleep(1)
        
        for video in response['items']:
            if video['id']['kind'] == 'youtube#video':
                video_id = video['id']['videoId']
                video_title = str(video['snippet']['title']).replace('&amp;', '')
                upload_date = str(video['snippet']['publishedAt']).split('T')[0]

                view_count, like_count, dislike_count, comment_count = get_video_details(video_id)
                
                record = (video_id, video_title, upload_date, view_count, like_count, dislike_count, comment_count)
                records.append(record)

        if os.path.exists('Stab_youtube_data.csv') == False:
            with open('Stab_youtube_data.csv', 'w', newline='', encoding='utf-8') as f:
                writer = csv.writer(f)
                writer.writerow(["Video_id","Video_title","Upload_date","View_count","Like_count","Dislike_count","Comment_count"])
                writer.writerows(records)
            f.close()
        else:
            with open('Stab_youtube_data.csv', 'a+', newline='', encoding='utf-8') as f:
                writer = csv.writer(f)
                writer.writerows(records)
            f.close()
        # Changing page
        try:
            if response['nextPageToken'] != None:
                page_token = "pageToken=" + response['nextPageToken']
        except:
            break

# %%
get_videos()

# %%
df = pd.read_csv('stab_youtube_data.csv')

# %%
df
# Out:
#         Video_id                                        Video_title  \
# 0    R4mebR724Pg  Mason Ho&#39;s 4 Favorite Electric Acid Boards...
# 1    RF_w8EQVFnY  Kolohe Andino vs Griffin Colapinto vs Ian Cran...
# 2    LUdqckbhzwY  A 100% Authentic New Zealand Surf Film | &#39;...
# 3    9rd31N1EOwQ  Dane Reynolds, Mason Ho, And Mikey February Fa...
# 4    w6CTQfDjW9o  More Raw Footage Of The WSL Finalists Warming ...
# ..           ...                                                ...
# 495  X9tU8ybzcFs                                           The Dock
# 496  ryCwJXsOVp0  All You Need To See From The Last Few Days On ...
# 497  bnVkEqCYD94  Drum Circles, Claims and Matt Wilkinson&#39;s ...
# 498  WD4ol1BRRWE                     The 2017 Rip Curl Pro Warm Ups
# 499  I_xPSKxqzuU  Brendon Gibbens Shot With Dane Reynolds For Te...
#
#     Upload_date  View_count  Like_count  Dislike_count  Comment_count
# 0    2021-09-17       19986         365              5             10
# 1    2021-09-16       17373         235              7             10
# 2    2021-09-13       34858        1026             11             81
# 3    2021-09-12       51184         751             22             37
# 4    2021-09-11       39323         476              6            104
# ..          ...         ...         ...            ...            ...
# 495  2017-07-15     9653162      119128           2650           2805
# 496  2017-06-26      120829         791             20             56
# 497  2017-05-02       19137         113              2              4
# 498  2017-04-27        4219          35              1              1
# 499  2017-01-16       21943         145              4             10
#
# [500 rows x 7 columns]
